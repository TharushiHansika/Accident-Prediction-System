# %%
from google.colab import drive
# Step 1: Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Step 2: Define the base dataset path in Google Drive
data_path = "/content/drive/MyDrive/TharuWorks/positive"  # Base path to the dataset

# %% [markdown]
# ## Split the Dataset

# %%
from sklearn.model_selection import train_test_split
import shutil
import glob
import os

# Step 3: List all video files across all subfolders of the dataset
# This will include files from `carcrash'`, `Crash dataset russian`, `Dachcam_dataset` directories.
video_files = glob.glob(os.path.join(data_path, '**', '*.mp4'), recursive=True)

# Step 4: Split the dataset into train, validation, and test sets
train_files, temp_files = train_test_split(video_files, test_size=0.3, random_state=42)
val_files, test_files = train_test_split(temp_files, test_size=0.5, random_state=42)

# Step 5: Create directories in Google Drive for train, validation, and test sets
train_dir = os.path.join(data_path, 'train')
val_dir = os.path.join(data_path, 'val')
test_dir = os.path.join(data_path, 'test')

os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Step 6: Copy the files to the respective Google Drive folders if they do not already exist

def copy_files_if_not_exists(file_list, destination_dir):
    for file in file_list:
        # Define the destination path for each file
        destination = os.path.join(destination_dir, os.path.basename(file))
        # Copy the file only if it does not already exist
        if not os.path.exists(destination):
            shutil.copy(file, destination)

# Train files
copy_files_if_not_exists(train_files, train_dir)

# Validation files
copy_files_if_not_exists(val_files, val_dir)

# Test files
copy_files_if_not_exists(test_files, test_dir)

print("Files have been successfully split and saved in Google Drive.")
# Out:
# Files have been successfully split and saved in Google Drive.

# %% [markdown]
# ## Frame Extraction

# %%
import cv2
import os
import math
import json

def ensure_dir(directory):
    """Ensure the output directory exists."""
    if not os.path.exists(directory):
        os.makedirs(directory)

def extract_frames(video_path, output_folder, interval_seconds=3):
    """
    Extract frames from a video based on the 3-second rule and log metadata.

    Parameters:
    - video_path: Path to the input video file.
    - output_folder: Path to save extracted frames.
    - interval_seconds: Time interval between frames in seconds (default = 3 seconds).
    """
    # Open the video file
    capture = cv2.VideoCapture(video_path)
    if not capture.isOpened():
        print(f"Error opening video file: {video_path}")
        return

    # Get video properties
    fps = int(capture.get(cv2.CAP_PROP_FPS))  # Frames per second
    total_frames = int(capture.get(cv2.CAP_PROP_FRAME_COUNT))  # Total number of frames
    duration = total_frames / fps  # Calculate video duration in seconds
    frame_interval = math.ceil(fps * interval_seconds)  # Frames to skip for 3-second rule

    print(f"Processing video: {video_path}")
    print(f"FPS: {fps}, Frame Interval: {frame_interval} frames, Duration: {duration:.2f} seconds")

    # Prepare the output folder
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    output_dir = os.path.join(output_folder, video_name)
    ensure_dir(output_dir)

    frame_count = 0
    saved_frames = 0

    while capture.isOpened():
        ret, frame = capture.read()
        if not ret:
            break  # End of video

        # Save frames at the calculated interval
        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_dir, f"frame_{frame_count}.jpg")
            if not os.path.exists(frame_filename):  # Avoid duplicates
                cv2.imwrite(frame_filename, frame)
                saved_frames += 1

        frame_count += 1

    capture.release()

    # Log metadata
    video_metadata = {
        "video_name": video_name,
        "video_path": video_path,
        "fps": fps,
        "duration": duration,
        "total_frames": total_frames,
        "saved_frames": saved_frames,
        "output_directory": output_dir
    }
    metadata_file_path = os.path.join(output_dir, "metadata_log.json")
    ensure_dir(os.path.dirname(metadata_file_path))

    # Write metadata to a JSON file
    with open(metadata_file_path, "w") as log:
        json.dump(video_metadata, log, indent=4)

    print(f"Extracted {saved_frames} frames from {video_path} to {output_dir}.")
    print(f"Metadata saved at {metadata_file_path}")

# Example Usage
video_dataset_folder = "/content/drive/MyDrive/TharuWorks/positive/train"  # Replace with your folder containing dashcam videos
output_frames_folder = "/content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train"  # Replace with your output folder

def process_video_dataset(video_folder, output_folder):
    """Process all videos in a dataset folder."""
    ensure_dir(output_folder)

    for root, _, files in os.walk(video_folder):
        for file in files:
            if file.endswith(('.mp4', '.avi', '.mov', '.mkv')):  # Supported video formats
                video_path = os.path.join(root, file)
                extract_frames(video_path, output_folder)

# Run the script
process_video_dataset(video_dataset_folder, output_frames_folder)
# Out:
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_15.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.40 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_15.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_15.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_15/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w7_14.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 8.34 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w7_14.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w7_14.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w7_14/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_99.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.60 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_99.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_99.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_99/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_118.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 10.00 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_118.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_118.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_118/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_37.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.00 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_37.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_37.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_37/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_115.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 3.50 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_115.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_115.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_115/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w5_4.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 9.41 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w5_4.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_4.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_4/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_40.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 5.23 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_40.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_40.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_40/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_41.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.50 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_41.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_41.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_41/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_43.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 5.77 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_43.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_43.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_43/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-55.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 14.93 seconds
# Extracted 5 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-55.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-55.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-55/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_32.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 9.87 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_32.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_32.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_32/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_127.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 2.57 seconds
# Extracted 1 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_127.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_127.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_127/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_65.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 5.03 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_65.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_65.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_65/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_55.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 15.80 seconds
# Extracted 6 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_55.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_55.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_55/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_100.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.73 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_100.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_100.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_100/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_5.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.50 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_5.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_5.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_5/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w5_8.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 11.10 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w5_8.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_8.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_8/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_81.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.83 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_81.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_81.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_81/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w5_40.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 4.17 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w5_40.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_40.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_40/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_91.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.43 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_91.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_91.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_91/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_28.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.97 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_28.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_28.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_28/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_83.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.83 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_83.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_83.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_83/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_113.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 2.97 seconds
# Extracted 1 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_113.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_113.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_113/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_39.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.37 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_39.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_39.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_39/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_38.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 8.87 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_38.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_38.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_38/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_132.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 3.27 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_132.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_132.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_132/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w5_43.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 8.07 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w5_43.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_43.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_43/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_12.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.03 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_12.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_12.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_12/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_47.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.73 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_47.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_47.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_47/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_40.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 9.30 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_40.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_40.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_40/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-4.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.87 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-4.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-4.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-4/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_16.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 5.93 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_16.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_16.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_16/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-7.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.03 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-7.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-7.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-7/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_95.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 15.57 seconds
# Extracted 6 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_95.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_95.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_95/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_94.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 12.70 seconds
# Extracted 5 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_94.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_94.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_94/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_51.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.97 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_51.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_51.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_51/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_80.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 18.23 seconds
# Extracted 7 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_80.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_80.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_80/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_57.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 9.30 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_57.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_57.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_57/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_3.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.07 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_3.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_3.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_3/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w7_13.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 12.31 seconds
# Extracted 5 frames from /content/drive/MyDrive/TharuWorks/positive/train/w7_13.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w7_13.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w7_13/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w5_48.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 6.52 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w5_48.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_48.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_48/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_58.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.40 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_58.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_58.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_58/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_2.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 10.97 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_2.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_2.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_2/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_84.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 16.67 seconds
# Extracted 6 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_84.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_84.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_84/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-40.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 17.23 seconds
# Extracted 6 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-40.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-40.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-40/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_19.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.03 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_19.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_19.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_19/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w5_19.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 6.69 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w5_19.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_19.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_19/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_29.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.20 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_29.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_29.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_29/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-8.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 12.63 seconds
# Extracted 5 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-8.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-8.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-8/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_20.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.37 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_20.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_20.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_20/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_39.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.13 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_39.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_39.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_39/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-65.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 14.23 seconds
# Extracted 5 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-65.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-65.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-65/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_39.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 5.60 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_39.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_39.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_39/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_17.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.00 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_17.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_17.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_17/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_106.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.03 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_106.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_106.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_106/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_96.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 10.30 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_96.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_96.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_96/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_54.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.70 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_54.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_54.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_54/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_114.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.57 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_114.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_114.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_114/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_8.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 5.23 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_8.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_8.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_8/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-27.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 8.50 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-27.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-27.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-27/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-64.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 5.60 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-64.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-64.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-64/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_61.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 18.23 seconds
# Extracted 7 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_61.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_61.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_61/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-19.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 8.70 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-19.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-19.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-19/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w5_6.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 8.48 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w5_6.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_6.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w5_6/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_46.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.77 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_46.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_46.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_46/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_28.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 3.93 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_28.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_28.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_28/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w3_56.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 10.53 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w3_56.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_56.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w3_56/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w10_32.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 5.00 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/train/w10_32.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_32.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w10_32/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w6-66.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 8.57 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/train/w6-66.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-66.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w6-66/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/train/w2_98.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 10.30 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/train/w2_98.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_98.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/train/w2_98/metadata_log.json

# %%
import cv2
import os
import math
import json

def ensure_dir(directory):
    """Ensure the output directory exists."""
    if not os.path.exists(directory):
        os.makedirs(directory)

def extract_frames(video_path, output_folder, interval_seconds=3):
    """
    Extract frames from a video based on the 3-second rule and log metadata.

    Parameters:
    - video_path: Path to the input video file.
    - output_folder: Path to save extracted frames.
    - interval_seconds: Time interval between frames in seconds (default = 3 seconds).
    """
    # Open the video file
    capture = cv2.VideoCapture(video_path)
    if not capture.isOpened():
        print(f"Error opening video file: {video_path}")
        return

    # Get video properties
    fps = int(capture.get(cv2.CAP_PROP_FPS))  # Frames per second
    total_frames = int(capture.get(cv2.CAP_PROP_FRAME_COUNT))  # Total number of frames
    duration = total_frames / fps  # Calculate video duration in seconds
    frame_interval = math.ceil(fps * interval_seconds)  # Frames to skip for 3-second rule

    print(f"Processing video: {video_path}")
    print(f"FPS: {fps}, Frame Interval: {frame_interval} frames, Duration: {duration:.2f} seconds")

    # Prepare the output folder
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    output_dir = os.path.join(output_folder, video_name)
    ensure_dir(output_dir)

    frame_count = 0
    saved_frames = 0

    while capture.isOpened():
        ret, frame = capture.read()
        if not ret:
            break  # End of video

        # Save frames at the calculated interval
        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_dir, f"frame_{frame_count}.jpg")
            if not os.path.exists(frame_filename):  # Avoid duplicates
                cv2.imwrite(frame_filename, frame)
                saved_frames += 1

        frame_count += 1

    capture.release()

    # Log metadata
    video_metadata = {
        "video_name": video_name,
        "video_path": video_path,
        "fps": fps,
        "duration": duration,
        "total_frames": total_frames,
        "saved_frames": saved_frames,
        "output_directory": output_dir
    }
    metadata_file_path = os.path.join(output_dir, "metadata_log.json")
    ensure_dir(os.path.dirname(metadata_file_path))

    # Write metadata to a JSON file
    with open(metadata_file_path, "w") as log:
        json.dump(video_metadata, log, indent=4)

    print(f"Extracted {saved_frames} frames from {video_path} to {output_dir}.")
    print(f"Metadata saved at {metadata_file_path}")

# Example Usage
video_dataset_folder = "/content/drive/MyDrive/TharuWorks/positive/val"  # Replace with your folder containing dashcam videos
output_frames_folder = "/content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val"  # Replace with your output folder

def process_video_dataset(video_folder, output_folder):
    """Process all videos in a dataset folder."""
    ensure_dir(output_folder)

    for root, _, files in os.walk(video_folder):
        for file in files:
            if file.endswith(('.mp4', '.avi', '.mov', '.mkv')):  # Supported video formats
                video_path = os.path.join(root, file)
                extract_frames(video_path, output_folder)

# Run the script
process_video_dataset(video_dataset_folder, output_frames_folder)
# Out:
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w3_52.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.03 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/val/w3_52.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w3_52.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w3_52/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w3_35.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.67 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/val/w3_35.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w3_35.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w3_35/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w6-96.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 3.10 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/val/w6-96.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w6-96.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w6-96/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w2_85.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 10.13 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/val/w2_85.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w2_85.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w2_85/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w2_97.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 8.60 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/val/w2_97.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w2_97.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w2_97/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w10_30.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.53 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/val/w10_30.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w10_30.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w10_30/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w10_2.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.77 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/val/w10_2.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w10_2.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w10_2/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w6-13.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 8.60 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/val/w6-13.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w6-13.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w6-13/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w7_10.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 8.93 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/val/w7_10.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w7_10.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w7_10/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w2_81.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 15.80 seconds
# Extracted 6 frames from /content/drive/MyDrive/TharuWorks/positive/val/w2_81.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w2_81.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w2_81/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w10_41.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 7.17 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/val/w10_41.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w10_41.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w10_41/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w5_14.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 5.24 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/val/w5_14.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w5_14.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w5_14/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w2_53.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.03 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/val/w2_53.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w2_53.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w2_53/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w10_91.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.50 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/val/w10_91.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w10_91.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w10_91/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/val/w6-43.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.87 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/val/w6-43.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w6-43.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/val/w6-43/metadata_log.json

# %%
import cv2
import os
import math
import json

def ensure_dir(directory):
    """Ensure the output directory exists."""
    if not os.path.exists(directory):
        os.makedirs(directory)

def extract_frames(video_path, output_folder, interval_seconds=3):
    """
    Extract frames from a video based on the 3-second rule and log metadata.

    Parameters:
    - video_path: Path to the input video file.
    - output_folder: Path to save extracted frames.
    - interval_seconds: Time interval between frames in seconds (default = 3 seconds).
    """
    # Open the video file
    capture = cv2.VideoCapture(video_path)
    if not capture.isOpened():
        print(f"Error opening video file: {video_path}")
        return

    # Get video properties
    fps = int(capture.get(cv2.CAP_PROP_FPS))  # Frames per second
    total_frames = int(capture.get(cv2.CAP_PROP_FRAME_COUNT))  # Total number of frames
    duration = total_frames / fps  # Calculate video duration in seconds
    frame_interval = math.ceil(fps * interval_seconds)  # Frames to skip for 3-second rule

    print(f"Processing video: {video_path}")
    print(f"FPS: {fps}, Frame Interval: {frame_interval} frames, Duration: {duration:.2f} seconds")

    # Prepare the output folder
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    output_dir = os.path.join(output_folder, video_name)
    ensure_dir(output_dir)

    frame_count = 0
    saved_frames = 0

    while capture.isOpened():
        ret, frame = capture.read()
        if not ret:
            break  # End of video

        # Save frames at the calculated interval
        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_dir, f"frame_{frame_count}.jpg")
            if not os.path.exists(frame_filename):  # Avoid duplicates
                cv2.imwrite(frame_filename, frame)
                saved_frames += 1

        frame_count += 1

    capture.release()

    # Log metadata
    video_metadata = {
        "video_name": video_name,
        "video_path": video_path,
        "fps": fps,
        "duration": duration,
        "total_frames": total_frames,
        "saved_frames": saved_frames,
        "output_directory": output_dir
    }
    metadata_file_path = os.path.join(output_dir, "metadata_log.json")
    ensure_dir(os.path.dirname(metadata_file_path))

    # Write metadata to a JSON file
    with open(metadata_file_path, "w") as log:
        json.dump(video_metadata, log, indent=4)

    print(f"Extracted {saved_frames} frames from {video_path} to {output_dir}.")
    print(f"Metadata saved at {metadata_file_path}")

# Example Usage
video_dataset_folder = "/content/drive/MyDrive/TharuWorks/positive/test"  # Replace with your folder containing dashcam videos
output_frames_folder = "/content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test"  # Replace with your output folder

def process_video_dataset(video_folder, output_folder):
    """Process all videos in a dataset folder."""
    ensure_dir(output_folder)

    for root, _, files in os.walk(video_folder):
        for file in files:
            if file.endswith(('.mp4', '.avi', '.mov', '.mkv')):  # Supported video formats
                video_path = os.path.join(root, file)
                extract_frames(video_path, output_folder)

# Run the script
process_video_dataset(video_dataset_folder, output_frames_folder)
# Out:
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w3_6.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 18.03 seconds
# Extracted 7 frames from /content/drive/MyDrive/TharuWorks/positive/test/w3_6.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w3_6.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w3_6/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w10_116.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 2.30 seconds
# Extracted 1 frames from /content/drive/MyDrive/TharuWorks/positive/test/w10_116.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_116.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_116/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w3_50.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 9.83 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/test/w3_50.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w3_50.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w3_50/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w2_31.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.37 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/test/w2_31.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_31.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_31/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w10_139.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 11.53 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/test/w10_139.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_139.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_139/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w10_101.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 4.43 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/test/w10_101.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_101.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_101/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w10_129.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.00 seconds
# Extracted 2 frames from /content/drive/MyDrive/TharuWorks/positive/test/w10_129.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_129.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_129/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w2_79.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 17.43 seconds
# Extracted 6 frames from /content/drive/MyDrive/TharuWorks/positive/test/w2_79.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_79.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_79/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w6-97.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.97 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/test/w6-97.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w6-97.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w6-97/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w2_30.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 10.53 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/test/w2_30.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_30.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_30/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w2_60.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 27.47 seconds
# Extracted 10 frames from /content/drive/MyDrive/TharuWorks/positive/test/w2_60.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_60.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_60/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w5_36.mp4
# FPS: 29, Frame Interval: 87 frames, Duration: 7.48 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/test/w5_36.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w5_36.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w5_36/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w2_51.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 9.13 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/test/w2_51.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_51.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_51/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w6-18.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 10.30 seconds
# Extracted 4 frames from /content/drive/MyDrive/TharuWorks/positive/test/w6-18.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w6-18.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w6-18/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w2_28.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 6.97 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/test/w2_28.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_28.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w2_28/metadata_log.json
# Processing video: /content/drive/MyDrive/TharuWorks/positive/test/w10_67.mp4
# FPS: 30, Frame Interval: 90 frames, Duration: 8.37 seconds
# Extracted 3 frames from /content/drive/MyDrive/TharuWorks/positive/test/w10_67.mp4 to /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_67.
# Metadata saved at /content/drive/MyDrive/TharuWorks/Frames/Positive_Extract/test/w10_67/metadata_log.json
